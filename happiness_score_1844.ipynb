# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('happiness_score_dataset.csv');

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
df.head(12)
# Out:
#         Country                           Region  Happiness Rank  \
# 0   Switzerland                   Western Europe               1
# 1       Iceland                   Western Europe               2
# 2       Denmark                   Western Europe               3
# 3        Norway                   Western Europe               4
# 4        Canada                    North America               5
# 5       Finland                   Western Europe               6
# 6   Netherlands                   Western Europe               7
# 7        Sweden                   Western Europe               8
# 8   New Zealand        Australia and New Zealand               9
# 9     Australia        Australia and New Zealand              10
# 10       Israel  Middle East and Northern Africa              11
# 11   Costa Rica      Latin America and Caribbean              12
#
#     Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0             7.587         0.03411                   1.39651  1.34951
# 1             7.561         0.04884                   1.30232  1.40223
# 2             7.527         0.03328                   1.32548  1.36058
# 3             7.522         0.03880                   1.45900  1.33095
# 4             7.427         0.03553                   1.32629  1.32261
# 5             7.406         0.03140                   1.29025  1.31826
# 6             7.378         0.02799                   1.32944  1.28017
# 7             7.364         0.03157                   1.33171  1.28907
# 8             7.286         0.03371                   1.25018  1.31967
# 9             7.284         0.04083                   1.33358  1.30923
# 10            7.278         0.03470                   1.22857  1.22393
# 11            7.226         0.04454                   0.95578  1.23788
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                    0.94143  0.66557                        0.41978
# 1                    0.94784  0.62877                        0.14145
# 2                    0.87464  0.64938                        0.48357
# 3                    0.88521  0.66973                        0.36503
# 4                    0.90563  0.63297                        0.32957
# 5                    0.88911  0.64169                        0.41372
# 6                    0.89284  0.61576                        0.31814
# 7                    0.91087  0.65980                        0.43844
# 8                    0.90837  0.63938                        0.42922
# 9                    0.93156  0.65124                        0.35637
# 10                   0.91387  0.41319                        0.07785
# 11                   0.86027  0.63376                        0.10583
#
#     Generosity  Dystopia Residual
# 0      0.29678            2.51738
# 1      0.43630            2.70201
# 2      0.34139            2.49204
# 3      0.34699            2.46531
# 4      0.45811            2.45176
# 5      0.23351            2.61955
# 6      0.47610            2.46570
# 7      0.36262            2.37119
# 8      0.47501            2.26425
# 9      0.43562            2.26646
# 10     0.33172            3.08854
# 11     0.25497            3.17728

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# 50%                    0.910245    1.029510                  0.696705
# 75%                    1.158448    1.214405                  0.811013
# max                    1.690420    1.402230                  1.025250
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  158.000000                     158.000000  158.000000
# mean     0.428615                       0.143422    0.237296
# std      0.150693                       0.120034    0.126685
# min      0.000000                       0.000000    0.000000
# 25%      0.328330                       0.061675    0.150553
# 50%      0.435515                       0.107220    0.216130
# 75%      0.549092                       0.180255    0.309883
# max      0.669730                       0.551910    0.795880
#
#        Dystopia Residual
# count         158.000000
# mean            2.098977
# std             0.553550
# min             0.328580
# 25%             1.759410
# 50%             2.095415
# 75%             2.462415
# max             3.602140

# %%
df.shape
# Out:
# (158, 12)

# %%
# observations
# Country and region contain text data 
# skeweness in Standard Error and Trust (Government Corruption)
# outliers 
# co-relation and multicollinearity

# %%
df.isna().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
lab_Enc = LabelEncoder()
df2 = lab_Enc.fit_transform(df['Country'])
df['Country'] = df2
df3 = lab_Enc.fit_transform(df['Country'])
df['Region'] = df3

# %%
df.head()
# Out:
#    Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135     135               1            7.587         0.03411
# 1       58      58               2            7.561         0.04884
# 2       37      37               3            7.527         0.03328
# 3      105     105               4            7.522         0.03880
# 4       24      24               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
# 2                        0.48357     0.34139            2.49204
# 3                        0.36503     0.34699            2.46531
# 4                        0.32957     0.45811            2.45176

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                           0.000000
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
plotnumber=1
for column in df:
    if(plotnumber <=12):
        plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
    plotnumber +=1  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hv/_q6ww8c93yd08npp6hh0nbz40000gn/T/ipykernel_5399/2574635291.py in <module>
#       4 for column in df:
#       5     if(plotnumber <=12):
# ----> 6         plt.subplot(3,3,plotnumber)
#       7         sns.distplot(df[column])
#       8     plotnumber +=1
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1270
#    1271     # First, search for an existing subplot with a matching spec.
# -> 1272     key = SubplotSpec._from_subplot_args(fig, args)
#    1273
#    1274     for ax in fig.axes:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     651                     num = int(num)
#     652                 if num < 1 or num > rows*cols:
# --> 653                     raise ValueError(
#     654                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#     655                 i = j = num
#
# ValueError: num must be 1 <= num <= 9, not 10

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                           0.000000
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
# sqrt(x)
df['Standard Error']= np.log(df["Standard Error"])

# %%
# df['Health (Life Expectancy)']= np.sqrt(df["Health (Life Expectancy)"])

# %%
df['Trust (Government Corruption)']= np.sqrt(df["Trust (Government Corruption)"])

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                           0.000000
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.484623
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
# df['Generosity']= np.sqrt(df["Generosity"])

# %%
dfCor = df.corr()
# df = df.drop(['Happiness Score'], axis=1)

# %%
collist = df.columns
noOfCol = collist.values
# df = df.drop(['Region'], axis=1)

# %%
dfCor = df.corr()

# %%
plt.figure(figsize =(15,20))
sns.heatmap(dfCor,annot = True)
plt.show()

# %%
df.corr()['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.210296
# Country                          0.083380
# Region                           0.083380
# Generosity                       0.180319
# Trust (Government Corruption)    0.354664
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %%
df = df.drop(['Happiness Rank','Standard Error','Region'],axis =1)

# %%
plt.figure(figsize =(20,25))
# df = df.drop(['Country'], axis=1)

graph = 1
for col in df:
    if graph <=12:
        plt.subplot(3,3,graph)
        ax=sns.boxplot(data=df[col])
        plt.xlabel(col)
        graph+=1
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from scipy.stats import zscore

# %%
zscore(df)
# Out:
#       Country  Happiness Score  Economy (GDP per Capita)    Family  \
# 0    1.238770         1.937360                  1.369621  1.320281
# 1   -0.449465         1.914581                  1.135226  1.514458
# 2   -0.909893         1.884792                  1.192861  1.361054
# 3    0.581016         1.880411                  1.525130  1.251922
# 4   -1.194920         1.797179                  1.194876  1.221204
# ..        ...              ...                       ...       ...
# 153  0.866043        -1.674055                 -1.552987 -0.800520
# 154 -1.436096        -1.783571                 -1.392303 -2.346860
# 155  1.260695        -2.076199                 -0.455245 -1.901086
# 156 -1.260695        -2.164688                 -2.067566 -2.118467
# 157  1.370321        -2.222513                 -1.586334 -3.134725
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                    1.263408  1.577438                       1.994534
# 1                    1.289434  1.332456                       0.190088
# 2                    0.992229  1.469659                       2.309792
# 3                    1.035145  1.605131                       1.704241
# 4                    1.118054  1.360416                       1.504447
# ..                        ...       ...                            ...
# 153                 -0.818610  1.087740                       2.625227
# 154                 -1.263362  0.372033                      -0.427838
# 155                  0.372199 -1.809238                       0.579860
# 156                 -1.649648 -2.064472                      -0.200879
# 157                 -1.404129 -0.426621                      -0.131999
#
#      Generosity  Dystopia Residual
# 0      0.471040           0.758258
# 1      1.575856           1.092857
# 2      0.824293           0.712335
# 3      0.868638           0.663893
# 4      1.748563           0.639337
# ..          ...                ...
# 153   -0.087228          -2.588925
# 154   -0.433117          -0.843967
# 155    1.856891          -3.208430
# 156   -0.316950          -0.481985
# 157   -0.558153          -0.963612
#
# [158 rows x 9 columns]

# %%
z_score = np.abs(zscore(df))
z_score
# Out:
#       Country  Happiness Score  Economy (GDP per Capita)    Family  \
# 0    1.238770         1.937360                  1.369621  1.320281
# 1    0.449465         1.914581                  1.135226  1.514458
# 2    0.909893         1.884792                  1.192861  1.361054
# 3    0.581016         1.880411                  1.525130  1.251922
# 4    1.194920         1.797179                  1.194876  1.221204
# ..        ...              ...                       ...       ...
# 153  0.866043         1.674055                  1.552987  0.800520
# 154  1.436096         1.783571                  1.392303  2.346860
# 155  1.260695         2.076199                  0.455245  1.901086
# 156  1.260695         2.164688                  2.067566  2.118467
# 157  1.370321         2.222513                  1.586334  3.134725
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                    1.263408  1.577438                       1.994534
# 1                    1.289434  1.332456                       0.190088
# 2                    0.992229  1.469659                       2.309792
# 3                    1.035145  1.605131                       1.704241
# 4                    1.118054  1.360416                       1.504447
# ..                        ...       ...                            ...
# 153                  0.818610  1.087740                       2.625227
# 154                  1.263362  0.372033                       0.427838
# 155                  0.372199  1.809238                       0.579860
# 156                  1.649648  2.064472                       0.200879
# 157                  1.404129  0.426621                       0.131999
#
#      Generosity  Dystopia Residual
# 0      0.471040           0.758258
# 1      1.575856           1.092857
# 2      0.824293           0.712335
# 3      0.868638           0.663893
# 4      1.748563           0.639337
# ..          ...                ...
# 153    0.087228           2.588925
# 154    0.433117           0.843967
# 155    1.856891           3.208430
# 156    0.316950           0.481985
# 157    0.558153           0.963612
#
# [158 rows x 9 columns]

# %%
np.where(z_score>3)
# Out:
# (array([128, 147, 155, 157]), array([7, 3, 8, 3]))

# %%
df_new = df[(z_score < 3).all(axis=1)]

# %%
df_new.shape
# Out:
# (154, 9)

# %%
# y = df_new['Happiness Score']
df.shape
# Out:
# (158, 9)

# %%
x = df_new.drop('Happiness Score', axis=1)
y = df_new['Happiness Score']

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
scalar_data = scalar.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
x_train,x_test,y_train,y_test = train_test_split(scalar_data,y,test_size=0.33, random_state=42)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(scalar_data)
# Out:
# array([7.55605203, 7.60343947, 7.46749936, 7.51315485, 7.43434194,
#        7.36973552, 7.39107768, 7.32818522, 7.26034647, 7.28273519,
#        7.29812492, 7.24689674, 7.23260932, 7.19408172, 7.16029129,
#        6.99548899, 6.9323816 , 6.96570204, 6.95986952, 6.87918898,
#        6.88713175, 6.84523477, 6.82165343, 6.74050382, 6.80652179,
#        6.78027246, 6.70072678, 6.5384531 , 6.59915258, 6.58331675,
#        6.47657988, 6.50478629, 6.47088991, 6.45979347, 6.39906246,
#        6.34674392, 6.3555195 , 6.32140037, 6.30818177, 6.28594728,
#        6.1216904 , 6.14008178, 6.13895109, 6.001527  , 5.98395465,
#        6.01943028, 6.0042454 , 5.99239553, 5.96045296, 5.93789449,
#        5.8956406 , 5.83816505, 5.90310637, 5.86607322, 5.85175248,
#        5.76958082, 5.85543525, 5.82445258, 5.83209032, 5.78956703,
#        5.80211764, 5.71811944, 5.77764885, 5.6875299 , 5.67929248,
#        5.73503016, 5.70633396, 5.61699187, 5.58100539, 5.5445154 ,
#        5.50232986, 5.47895901, 5.45575465, 5.29251127, 5.38107656,
#        5.35584449, 5.28317475, 5.24231235, 5.2922558 , 5.22799122,
#        5.20410958, 5.21498816, 5.21583882, 5.11521104, 5.13900176,
#        5.05662464, 5.10114851, 5.05832635, 5.10978642, 5.10060548,
#        5.03024787, 5.01482395, 5.01373085, 4.97415609, 4.96514743,
#        4.8629696 , 4.89841605, 4.91770531, 4.8972335 , 4.86391006,
#        4.83029707, 4.80748311, 4.84222692, 4.78342423, 4.80006165,
#        4.80934435, 4.73774887, 4.73406131, 4.70543495, 4.69823586,
#        4.66536192, 4.69811366, 4.65126741, 4.61582367, 4.61377999,
#        4.56314629, 4.5717061 , 4.56710597, 4.54287138, 4.50947588,
#        4.52216445, 4.52495939, 4.50432986, 4.45049979, 4.42750384,
#        4.35889565, 4.33343828, 4.33985408, 4.25781733, 4.28558208,
#        4.31292002, 4.24322199, 4.1657619 , 4.19592643, 4.07767204,
#        4.024952  , 4.00816704, 3.99728245, 3.96468262, 3.94576742,
#        3.92490013, 3.91307125, 3.8588651 , 3.8428174 , 3.79085174,
#        3.68912805, 3.65071671, 3.66694349, 3.66764153, 3.60310964,
#        3.5848874 , 3.36610948, 3.33968004, 2.90728199])

# %%
lr.score(x_test,y_test)
# Out:
# 0.9993694178642597

# %%
from sklearn.metrics import r2_score

# %%
pred_train = lr.predict(x_train)
pred_test = lr.predict(x_test)
print("Accuracy score")
print(r2_score(y_train,pred_train))
print(r2_score(y_test,pred_test))
# Out:
# Accuracy score
# 0.9993902286939418
# 0.9993694178642597
